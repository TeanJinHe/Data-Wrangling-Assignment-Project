# %% [markdown]
# # DATA PREPARATION

# %%
pip install missingno
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
vegetation_data = pd.read_csv("Vegetation_-_Central_Valley_Flood_Protection_Planning_Area_Update_-_2016_edited.csv")
vegetation_data
# Out:
#        OBJECTID                                            MCVName  \
# 0             1  Populus fremontii – Fraxinus velutina – Salix ...
# 1             2                                             Barren
# 2             3               Eucalyptus (globulus, camaldulensis)
# 3             4                 Salix gooddingii – Salix laevigata
# 4             5                                              Urban
# ...         ...                                                ...
# 46113     46114  Naturalized warm-temperate riparian and wetlan...
# 46114     46115       Typha (angustifolia, domingensis, latifolia)
# 46115     46116       Typha (angustifolia, domingensis, latifolia)
# 46116     46117  Californian mixed annual/perennial freshwater ...
# 46117     46118                       Cropland, Orchard - Vineyard
#
#                        MCVLevel  MapCode  \
# 0                      Alliance       15
# 1                           NaN      200
# ...

# %%
vegetation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46118 entries, 0 to 46117
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OBJECTID         46118 non-null  int64
#  1   MCVName          46118 non-null  object
#  2   MCVLevel         39222 non-null  object
#  3   MapCode          46118 non-null  int64
#  4   MapClass         46118 non-null  object
#  5   CV_Group         46118 non-null  object
#  6   HT_CODE          39288 non-null  object
#  7   SIZE_CATEG       19541 non-null  object
#  8   PER_HARDWO       42952 non-null  float64
#  9   PER_CONIFE       42952 non-null  float64
#  10  PER_TREE         46118 non-null  float64
#  11  PER_SHRUB        46118 non-null  float64
#  12  HERB_CODE        42952 non-null  object
#  13  PER_TOTAL        42952 non-null  float64
#  14  ISOLATED_T       17127 non-null  object
#  15  RESTORATIO       696 non-null    object
# ...

# %%
msno.matrix(vegetation_data)
# Out:
# <AxesSubplot:>

# %%
vege_df = vegetation_data.drop(['PER_CONIFE','ISOLATED_T','RESTORATIO','Comments','Source','CaCode','CommunityLink'],axis=1)
vege_df
# Out:
#        OBJECTID                                            MCVName  \
# 0             1  Populus fremontii – Fraxinus velutina – Salix ...
# 1             2                                             Barren
# 2             3               Eucalyptus (globulus, camaldulensis)
# 3             4                 Salix gooddingii – Salix laevigata
# 4             5                                              Urban
# ...         ...                                                ...
# 46113     46114  Naturalized warm-temperate riparian and wetlan...
# 46114     46115       Typha (angustifolia, domingensis, latifolia)
# 46115     46116       Typha (angustifolia, domingensis, latifolia)
# 46116     46117  Californian mixed annual/perennial freshwater ...
# 46117     46118                       Cropland, Orchard - Vineyard
#
#                        MCVLevel  MapCode  \
# 0                      Alliance       15
# 1                           NaN      200
# ...

# %%
vege_df = vege_df[vege_df['GlobalRank'].notna()]
vege_df
# Out:
#        OBJECTID                                            MCVName  \
# 0             1  Populus fremontii – Fraxinus velutina – Salix ...
# 2             3               Eucalyptus (globulus, camaldulensis)
# 3             4                 Salix gooddingii – Salix laevigata
# 5             6  Californian mixed annual/perennial freshwater ...
# 8             9               Eucalyptus (globulus, camaldulensis)
# ...         ...                                                ...
# 46106     46107                Phragmites australis – Arundo donax
# 46109     46110                 Salix gooddingii – Salix laevigata
# 46114     46115       Typha (angustifolia, domingensis, latifolia)
# 46115     46116       Typha (angustifolia, domingensis, latifolia)
# 46116     46117  Californian mixed annual/perennial freshwater ...
#
#                        MCVLevel  MapCode  \
# 0                      Alliance       15
# 2      Semi-natural Association        6
# ...

# %%
vege_df = vege_df[vege_df['SIZE_CATEG'].notna()]
vege_df
# Out:
#        OBJECTID                                            MCVName  \
# 0             1  Populus fremontii – Fraxinus velutina – Salix ...
# 2             3               Eucalyptus (globulus, camaldulensis)
# 3             4                 Salix gooddingii – Salix laevigata
# 8             9               Eucalyptus (globulus, camaldulensis)
# 9            10              Platanus racemosa – Quercus agrifolia
# ...         ...                                                ...
# 46041     46042              Platanus racemosa – Quercus agrifolia
# 46085     46086                            Quercus lobata Riparian
# 46104     46105                            Quercus lobata Riparian
# 46105     46106                 Salix gooddingii – Salix laevigata
# 46109     46110                 Salix gooddingii – Salix laevigata
#
#                        MCVLevel  MapCode  \
# 0                      Alliance       15
# 2      Semi-natural Association        6
# ...

# %%
vege_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18662 entries, 0 to 46109
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OBJECTID         18662 non-null  int64
#  1   MCVName          18662 non-null  object
#  2   MCVLevel         18662 non-null  object
#  3   MapCode          18662 non-null  int64
#  4   MapClass         18662 non-null  object
#  5   CV_Group         18662 non-null  object
#  6   HT_CODE          18662 non-null  object
#  7   SIZE_CATEG       18662 non-null  object
#  8   PER_HARDWO       18662 non-null  float64
#  9   PER_TREE         18662 non-null  float64
#  10  PER_SHRUB        18662 non-null  float64
#  11  HERB_CODE        18662 non-null  object
#  12  PER_TOTAL        18662 non-null  float64
#  13  CLEARING_D       18662 non-null  object
#  14  INVASIVE_P       18662 non-null  object
#  15  Ortho_NAIP_Year  18662 non-null  int64
# ...

# %%
bool_series = vege_df.duplicated()
bool_series
# Out:
# 0        False
# 2        False
# 3        False
# 8        False
# 9        False
#          ...
# 46041    False
# 46085    False
# 46104    False
# 46105    False
# 46109    False
# Length: 18662, dtype: bool

# %%
alt.Chart(vege_df).mark_circle().encode(
x=':Q',
y='Happy Planet Index:Q',
color='Region:N',
tooltip=['Country', 'Region', 'Wellbeing (0-10)', 'Happy Planet Index', 'Life Expectancy (years)'],
)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\altair\vegalite\v5\api.py in to_dict(self, *args, **kwargs)
#    2511             copy.data = core.InlineData(values=[{}])
#    2512             return super(Chart, copy).to_dict(*args, **kwargs)
# -> 2513         return super().to_dict(*args, **kwargs)
#    2514
#    2515     def add_params(self, *params) -> Self:
#
# D:\Anaconda\lib\site-packages\altair\vegalite\v5\api.py in to_dict(self, *args, **kwargs)
#     829         copy = self.copy(deep=False)  # type: ignore[attr-defined]
#     830         original_data = getattr(copy, "data", Undefined)
# --> 831         copy.data = _prepare_data(original_data, context)
#     832
#     833         if original_data is not Undefined:
#
# D:\Anaconda\lib\site-packages\altair\vegalite\v5\api.py in _prepare_data(data, context)
# ...
